# %% [markdown]
# <a href="https://colab.research.google.com/github/sh1027/cv-short-tutorial/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import some common libraries
import numpy as np
import os, cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# # 画像の読み込み

# %% [markdown]
# 画像をダウンロード

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
color_img = cv2.imread("./input.jpg")

# %% [markdown]
# カラー画像の表示，画像サイズの確認

# %%
print("画像サイズ:", color_img.shape)
cv2_imshow(color_img)
# Out:
# 画像サイズ: (480, 640, 3)
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FEE0D5EE3D0>

# %% [markdown]
# カラー画像をグレーに変換
#
# グレー画像の表示，画像サイズの確認

# %%
gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
print("画像サイズ", gray_img.shape)
cv2_imshow(gray_img)
# Out:
# 画像サイズ (480, 640)
# <PIL.Image.Image image mode=L size=640x480 at 0x7FEE0D5C0990>

# %% [markdown]
# # 画像の中身の確認

# %% [markdown]
# 画像の中身を表示してみる

# %%
color_img
# Out:
# array([[[140, 160, 118],
#         [128, 156, 120],
#         [123, 138, 111],
#         ...,
#         [ 67, 109,  92],
#         [ 62,  88,  52],
#         [ 78, 100,  72]],
#
#        [[125, 173, 125],
#         [122, 149, 109],
#         [102, 133,  96],
#         ...,
#         [ 94, 104,  98],
#         [ 59,  95,  71],
#         [ 78, 114, 100]],
#
#        [[108, 157, 119],
#         [110, 157, 119],
#         [ 84, 151, 112],
#         ...,
#         [ 69, 124,  97],
#         [ 78, 110,  79],
#         [ 88, 104,  80]],
#
#        ...,
#
#        [[ 21,  19,  19],
#         [ 21,  19,  19],
#         [ 17,  18,  16],
#         ...,
#         [155, 156, 177],
#         [155, 153, 175],
#         [158, 155, 177]],
#
#        [[ 17,  16,  18],
#         [ 22,  22,  22],
#         [ 16,  18,  18],
#         ...,
#         [175, 173, 195],
#         [174, 168, 191],
#         [162, 154, 177]],
#
#        [[ 14,  13,  15],
#         [ 22,  24,  25],
#         [ 17,  19,  19],
# ...

# %% [markdown]
# # 配列を操作して画像で遊んでみる

# %% [markdown]
# カラー画像をRGB成分に分離してみる

# %%
# color_imgでは，3つ目の軸がカラーチャンネルを表していて，B,G,Rの順に入っている．
red_img = color_img.copy()
red_img[:, :, (0, 1)] = 0
green_img = color_img.copy()
green_img[:, :, (0, 2)] = 0
blue_img = color_img.copy()
blue_img[:, :, (1, 2)] = 0
cv2_imshow(red_img)
cv2_imshow(green_img)
cv2_imshow(blue_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FEE04E500D0>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FEE04E503D0>
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FEE04E904D0>

# %% [markdown]
# ネガポジ変換してみる

# %%
nega_img = 255 - color_img
cv2_imshow(nega_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FEE04E2D110>

# %% [markdown]
# #畳み込み処理をしてみる

# %% [markdown]
# 画像をぼかしてみる

# %%
# ぼかしフィルターサイズの設定．大きいほどぼけが強くなる
filter_size = 3

height, width = gray_img.shape

# ぼかしフィルターの設定
filter = np.ones((filter_size, filter_size)) / filter_size ** 2

# 出力画像の初期化
blur_height, blur_width = height - filter_size + 1, width - filter_size + 1
blur_img = np.zeros((blur_height, blur_width), gray_img.dtype)

# 畳み込み処理
for h in range(blur_height):
  for w in range(blur_width):
    patch = gray_img[h:h+filter_size,w:w+filter_size]
    blur_img[h, w] = np.sum(patch * filter)

cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=638x478 at 0x7FEE04E17C50>

# %% [markdown]
# 画像のエッジ検出をしてみる

# %%
src_img = gray_img.copy()
# src_img = blur_img.copy() # blur_imgのエッジ検出をするとどうなるか？
height, width = src_img.shape

# エッジフィルターの設定
filter = np.array([[-1,2,-1],[-1,2,-1],[-1,2,-1]]) # 縦のエッジを検出
# filter = np.array([[-1,-1,-1],[2,2,2],[-1,-1,-1]]) # 横のエッジを検出
filter_size = 3

# 出力画像の初期化
edge_height, edge_width = height - filter_size + 1, width - filter_size + 1
edge_img = np.zeros((edge_height, edge_width), src_img.dtype)

# 畳み込み処理
for h in range(edge_height):
  for w in range(edge_width):
    patch = src_img[h:h+filter_size,w:w+filter_size]
    edge_img[h, w] = np.sum(patch * filter)

cv2_imshow(edge_img)
# Out:
# <PIL.Image.Image image mode=L size=636x476 at 0x7FEE04DE6E50>
